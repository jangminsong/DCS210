# %% [markdown]
# <a href="https://colab.research.google.com/github/jangminsong/DCS210/blob/main/HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#JANGMIN SONG
#HW4

# %%
install.packages("tidyverse")
install.packages("skimr")
library(tidyverse)
library(skimr)

# %%
brexit <- read.csv("brexit.csv")

# %%
ggplot(brexit, aes(x="",y="", fill=opinion)) +
  geom_col() +
  coord_polar(theta = "y") +
  labs(
    title = "Was Britain right/wrong to vote to leave EU?",
    subtitle = "YouGov Survey Results, 2-3 September 2019",
    caption = "Source: bit.ly/2lCJZVg",
    y = "",
    x = "") +
    theme_void()
# Out:
# plot without title

# %%
ggplot(brexit, aes(y = opinion, fill=opinion)) +
  geom_bar() +
  labs(
    title = "Was Britain right/wrong to vote to leave EU?",
    subtitle = "YouGov Survey Results, 2-3 September 2019",
    caption = "Source: bit.ly/2lCJZVg",
    y = "Opinion",
    x = "Count"
  )
# Out:
# plot without title

# %%
ggplot(brexit, aes(x = opinion, fill = opinion)) +
  geom_bar() +
  facet_wrap(~region, nrow = 3) +
  labs(
    title = "Was Britain right/wrong to vote to leave EU?",
    subtitle = "YouGov Survey Results, 2-3 September 2019",
    caption = "Source: bit.ly/2lCJZVg",
    y = "Count",
    x = "Opinion"
  )
# Out:
# plot without title
