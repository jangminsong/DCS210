# %% [markdown]
# <a href="https://colab.research.google.com/github/jangminsong/DCS210/blob/Project/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("tidyverse")
install.packages("tidymodels")
install.packages("openintro")
library(tidyverse)
library(tidymodels)
library(openintro)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘future.apply’, ‘numDeriv’, ‘progressr’, ‘SQUAREM’, ‘Rcpp’, ‘lava’, ‘listenv’, ‘parallelly’, ‘prodlim’, ‘future’, ‘warp’, ‘iterators’, ‘lhs’, ‘DiceDesign’, ‘patchwork’, ‘globals’, ‘clock’, ‘gower’, ‘ipred’, ‘timeDate’, ‘furrr’, ‘slider’, ‘foreach’, ‘GPfit’, ‘modelenv’, ‘conflicted’, ‘dials’, ‘hardhat’, ‘infer’, ‘modeldata’, ‘parsnip’, ‘recipes’, ‘rsample’, ‘tune’, ‘workflows’, ‘workflowsets’, ‘yardstick’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘airports’, ‘cherryblossom’, ‘usdata’
#
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ...

# %%
#4
score_bty_fit <- lm(bty_avg ~ pic_color, data = evals)

plot(evals$bty_avg ~ evals$pic_color,
     main = "Picture Color vs Beauty Score",
     xlab = "Picture Color", ylab = "Beauty Score")
abline(score_bty_fit, col = "orange")

tidy(score_bty_fit)
summary(score_bty_fit)
# Out:
#   term           estimate  std.error statistic p.value
# 1 (Intercept)     5.378051 0.1660378 32.39053  7.373945e-121
# 2 pic_colorcolor -1.154742 0.1820820 -6.34188   5.421530e-10
# Call:
# lm(formula = bty_avg ~ pic_color, data = evals)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.5563 -1.0563 -0.0563  1.1097  3.9437
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)      5.3781     0.1660  32.391  < 2e-16 ***
# pic_colorcolor  -1.1547     0.1821  -6.342 5.42e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.466 on 461 degrees of freedom
# Multiple R-squared:  0.08024,	Adjusted R-squared:  0.07825
# F-statistic: 40.22 on 1 and 461 DF,  p-value: 5.422e-10
# Plot with title “Picture Color vs Beauty Score”

# %%
#4
score_bty_fit <- lm(score ~ pic_color, data = evals)

plot(evals$score ~ evals$pic_color,
     main = "Picture Color vs Evaluation Score",
     xlab = "Picture Color", ylab = "Evaluation Score")
abline(score_bty_fit, col = "blue")

tidy(score_bty_fit)
summary(score_bty_fit)
# Out:
#   term           estimate   std.error  statistic p.value
# 1 (Intercept)     4.3615385 0.06090445 71.612806 6.367322e-252
# 2 pic_colorcolor -0.2246553 0.06678965 -3.363625  8.334246e-04
# Call:
# lm(formula = score ~ pic_color, data = evals)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8369 -0.3615  0.1385  0.4385  0.8631
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)     4.36154    0.06090  71.613  < 2e-16 ***
# pic_colorcolor -0.22466    0.06679  -3.364 0.000833 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5379 on 461 degrees of freedom
# Multiple R-squared:  0.02395,	Adjusted R-squared:  0.02184
# F-statistic: 11.31 on 1 and 461 DF,  p-value: 0.0008334
# Plot with title “Picture Color vs Evaluation Score”
